# %% [markdown]
# # Optuna Dashboard - BNR Exchange Rate Models
#
# Acest notebook oferÄƒ posibilitatea de a porni serverul local pentru **Optuna Dashboard** direct din Jupyter, pentru a vizualiza interactiv progresul, importanÈ›a parametrilor È™i rezultatele hyperparameter tuning-ului pentru modelele XGBoost, SARIMA È™i Prophet.
#
# **InstrucÈ›iuni de Utilizare:**
# RuleazÄƒ celula corespunzÄƒtoare modelului pe care doreÈ™ti sÄƒ-l analizezi. Dashboard-ul va deveni imediat disponibil deschizÃ¢nd browser-ul la adresa `http://localhost:<port>` (de exemplu `http://localhost:7771` pentru XGBoost).
# Pentru a Ã®nchide serverul È™i a trece la alt model, opreÈ™te manual execuÈ›ia celulei curente (Stop / Interrupt Kernel).

# %% [markdown]
# ### 1. Vizualizare XGBoost (Port 7771)

# %%
import optuna
from optuna_dashboard import run_server

storage = "sqlite:///outputs/optuna_studies/xgboost_optimization.db"
run_server(storage, port=7771)

# %% [markdown]
# ### 2. Vizualizare SARIMA (Port 7772)

# %%
import optuna
from optuna_dashboard import run_server

storage = "sqlite:///outputs/optuna_studies/sarima_optimization.db"
run_server(storage, port=7772)

# %% [markdown]
# ### 3. Vizualizare Prophet (Port 7773)

# %%
import optuna
from optuna_dashboard import run_server

storage = "sqlite:///outputs/optuna_studies/prophet_optimization.db"
run_server(storage, port=7773)
